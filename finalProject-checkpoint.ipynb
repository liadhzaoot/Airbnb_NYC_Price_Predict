# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import seaborn as sns
import matplotlib.colors as colors
from matplotlib import pyplot as plt
from sklearn import metrics
import numpy as np


# linear
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# random forest
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data importing

# %%
df = pd.read_csv(r'C:\Users\liad hazoot\Desktop\AB_NYC_2019.csv')

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# Now we saw that we have alot of null elements, lets fill them.

# %% [markdown]
# # Cleaning Data

# %%
df.fillna({'reviews_per_month':0}, inplace=True)
df.fillna({'name':"NoName"}, inplace=True)
df.fillna({'host_name':"NoName"}, inplace=True)
df.fillna({'last_review':"NotReviewed"}, inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# All the fileds fiiled, lets check the price field

# %%
df['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# Check price 0, if exist -> delete

# %%
price_zero = df['price'][df['price'] == 0]
price_zero.count()
# Out:
# 11

# %%
df = df[df['price'] != 0]

# %% [markdown]
# The price is between 0 to 10,000, lets check the less then 1000 price

# %%
hist_lower_1000 = df["price"][df["price"]<1000].hist()

# %% [markdown]
# we can see that most airbnb apartments are less then 1000, lets delete them

# %%
df=df[df["price"]<1000]

# %% [markdown]
# There are 221 unique neighbourhoods in NYC as per this data set. Most listings are in Williamsburg

# %%
df['neighbourhood'].value_counts()
# Out:
# Williamsburg          3907
# Bedford-Stuyvesant    3697
# Harlem                2650
# Bushwick              2460
# Hell's Kitchen        1948
#                       ...
# Willowbrook              1
# Woodrow                  1
# New Dorp                 1
# Fort Wadsworth           1
# Rossville                1
# Name: neighbourhood, Length: 221, dtype: int64

# %% [markdown]
# lets check the neighbourhood that more then 200

# %%
dfnh = df.groupby("neighbourhood").filter(lambda x: x['neighbourhood'].count() > 200)
len(dfnh)
# Out:
# 42019

# %% [markdown]
# Most data is convert 42,000/48,000

# %% [markdown]
# lets look at neighbourhood groups

# %%
df['neighbourhood_group'].describe()
# Out:
# count         48586
# unique            5
# top       Manhattan
# freq          21447
# Name: neighbourhood_group, dtype: object

# %% [markdown]
# There are 5 uniqe neighbourhood group, lets check how many apartments has each neighbourhood group

# %%
df['neighbourhood_group'].value_counts()
# Out:
# Manhattan        21447
# Brooklyn         20028
# Queens            5653
# Bronx             1088
# Staten Island      370
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# lets check the mean price for each neighbourhood

# %%
ng_price = df.groupby("neighbourhood_group")["price"].mean()
ng_price
# Out:
# neighbourhood_group
# Bronx             84.521140
# Brooklyn         117.288246
# Manhattan        177.375017
# Queens            94.528038
# Staten Island     96.148649
# Name: price, dtype: float64

# %% [markdown]
# we can that the data is ok and Manhattan is the most expensive and Bronx is the least expensive place to live

# %% [markdown]
# lets see this data in scater plot

# %%
plott = df.plot.scatter(x="neighbourhood_group",y="price",colormap = 'viridis')

# %% [markdown]
# Here we can note that Brooklyn and Manhattan tend to have more listings with price>150.

# %%
df["room_type"].describe()
df["room_type"].value_counts()
# Out:
# Entire home/apt    25164
# Private room       22268
# Shared room         1154
# Name: room_type, dtype: int64

# %%
df.groupby("room_type")["price"].mean()
# Out:
# room_type
# Entire home/apt    192.948140
# Private room        84.581777
# Shared room         66.116118
# Name: price, dtype: float64

# %% [markdown]
# Entire home / apt is the most expensive room type

# %%
# ### Lets see the distributuion of price and neighbourhood group. 
# plott=sns.catplot(x="neighbourhood_group",y="price",hue="room_type", kind="swarm", data=df)
# plott

# %% [markdown]
# after we saw that the room type affects on the price, lets check the name coulmn (listing description).
# lets check the name length.

# %%
name_length_df = df["name"].str.len()
df["name_length"] = name_length_df
df["name_length"]
# Out:
# 0        34
# 1        21
# 2        35
# 3        31
# 4        48
#          ..
# 48890    47
# 48891    45
# 48892    39
# 48893    36
# 48894    49
# Name: name_length, Length: 48586, dtype: int64

# %% [markdown]
# lets check if the name length effects on number of reviews

# %%
ax = df.plot.scatter(x='name_length',
                    y='number_of_reviews')

# %% [markdown]
# name length < 50 has more reviews, now lets check the price and name length

# %%
ax = df[df["name_length"] < 50].plot.scatter(x="price",
                    y='name_length')

# %% [markdown]
# Analysing the minimum nights

# %%
df['minimum_nights'].describe()
# Out:
# count    48586.000000
# mean         6.974931
# std         20.276877
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %% [markdown]
# there are minimum nights between 1 to 1250 and the mean is < 7

# %%
df['minimum_nights'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# the most listening is < 100, lets get a closer look

# %%
df['minimum_nights'][df['minimum_nights'] < 100 ].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# we see that the most is under 40

# %%
df['minimum_nights'][df['minimum_nights'] > 40 ].count()
# Out:
# 483

# %%
sns.scatterplot(df['price'],df['minimum_nights'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='minimum_nights'>

# %%
sns.boxplot(df['minimum_nights'])
# Out:
# <AxesSubplot:xlabel='minimum_nights'>

# %% [markdown]
# lets change all minimum nights that > 40 to 40

# %%
df['minimum_nights'][df['minimum_nights'] > 40 ] = 40

# %%
#check
df['minimum_nights'].describe()
# Out:
# count    48586.000000
# mean         6.046454
# std          9.005319
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max         40.000000
# Name: minimum_nights, dtype: float64

# %% [markdown]
# lets look at reviews per mounth

# %%
df['reviews_per_month'].describe()
# Out:
# count    48586.000000
# mean         1.095313
# std          1.599884
# min          0.000000
# 25%          0.040000
# 50%          0.380000
# 75%          1.600000
# max         58.500000
# Name: reviews_per_month, dtype: float64

# %% [markdown]
# check if reviews per mouth effect on price

# %%
#most of the reviews_per_month <5 lets check them
rpm_df = df[df["reviews_per_month"]<5]
rpm_df.plot.scatter(x = 'reviews_per_month',
                y = 'price')
# Out:
# <AxesSubplot:xlabel='reviews_per_month', ylabel='price'>

# %%
rpm_df = rpm_df[rpm_df["reviews_per_month"] == 0]
len(rpm_df)
# Out:
# 9890

# %%
rpm_df["price"].hist()
# Out:
# <AxesSubplot:>

# %%
df["reviews_per_month"].corr(df["price"])
# Out:
# -0.054212740375104755

# %% [markdown]
# there are no strongly corralation between reviews per month and price

# %% [markdown]
# lets look at the availability

# %%
df['availability_365'].describe()
# Out:
# count    48586.000000
# mean       112.365928
# std        131.383634
# min          0.000000
# 25%          0.000000
# 50%         44.000000
# 75%        225.000000
# max        365.000000
# Name: availability_365, dtype: float64

# %% [markdown]
# lets look how many rows have 0 availability

# %%
# df[df['availability_365'] == 0].count()

# %%
# df[df['availability_365'] == 0] = 107

# %%
# df.plot.scatter(x = "availability_365",y = "price")

# %%
sns.boxplot(df["availability_365"])
# Out:
# <AxesSubplot:xlabel='availability_365'>

# %% [markdown]
# no outliers

# %%
df.plot.scatter(x = "availability_365",y = 'price')
# Out:
# <AxesSubplot:xlabel='availability_365', ylabel='price'>

# %% [markdown]
# lets drop the columns that not usful in train and prediction

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='longitude', y='latitude', hue='neighbourhood_group',s=20, data=df)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# Dropping the unnecessary columns

# %%
df.drop(["name",'last_review',
         "latitude",'longitude',
         'host_id','host_name',
         'id'], axis=1, inplace=True)

# %%
df.dtypes
# Out:
# neighbourhood_group                object
# neighbourhood                      object
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# name_length                         int64
# dtype: object

# %%
### Plotting correlation matrix 
corr = df.corr(method='pearson')
plt.figure(figsize=(15,8))
sns.heatmap(corr, annot=True)
df.columns
# Out:
# Index(['neighbourhood_group', 'neighbourhood', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365', 'name_length'],
#       dtype='object')

# %% [markdown]
# # Mechine Learning

# %% [markdown]
# # Start with Linear Regression

# %%
dataset_onehot1 = pd.get_dummies(df, columns=['neighbourhood_group',"room_type"], prefix = ['ng',"rt"],drop_first=True)
dataset_onehot1.drop(["neighbourhood"], axis=1, inplace=True)

# %%
X1= dataset_onehot1.loc[:, dataset_onehot1.columns != 'price']
Y1 = dataset_onehot1["price"]
x_train1, x_test1, y_train1, y_test1 = train_test_split(X1, Y1, test_size=0.20, random_state=42)

# %%
dataset_onehot1.shape
# Out:
# (48586, 13)

# %%
### Fitting Linear regression
reg1 = LinearRegression().fit(x_train1, y_train1)

# %%
### R squared value
reg1.score(x_train1, y_train1)
# Out:
# 0.32444496440938064

# %%
# let's look inside the model
print("b1:",reg1.coef_)
print("b0:",reg1.intercept_)
# Out:
# b1: [-1.63255211e+00 -1.51439668e-01 -3.49686623e+00  1.11001935e-01
#   1.51245311e-01  7.42181855e-01  2.63729398e+01  7.26724437e+01
#   9.33133988e+00 -5.23839502e+00 -1.00953864e+02 -1.29336552e+02]
# b0: 117.65180566199133

# %%
### Predicting 
y_pred1 = reg1.predict(x_test1)

# %%
Coeff1 = pd.DataFrame(columns=["Variable","Coefficient"])
Coeff1["Variable"]=x_train1.columns
Coeff1["Coefficient"]=reg1.coef_
Coeff1.sort_values("Coefficient")
# Out:
#                           Variable  Coefficient
# 11                  rt_Shared room  -129.336552
# 10                 rt_Private room  -100.953864
# 9                 ng_Staten Island    -5.238395
# 2                reviews_per_month    -3.496866
# 0                   minimum_nights    -1.632552
# 1                number_of_reviews    -0.151440
# 3   calculated_host_listings_count     0.111002
# 4                 availability_365     0.151245
# 5                      name_length     0.742182
# 8                        ng_Queens     9.331340
# 6                      ng_Brooklyn    26.372940
# 7                     ng_Manhattan    72.672444

# %% [markdown]
# lets try to clean more our data

# %%
sns.violinplot(df["room_type"],df["price"])
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='price'>

# %%
df=df[df["price"]<250]
sns.violinplot(df["room_type"],df["price"])
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='price'>

# %% [markdown]
# looking better, there are less oulier.

# %%
dataset_onehot2 = pd.get_dummies(df, columns=['neighbourhood_group',"room_type"], prefix = ['ng',"rt"],drop_first=True)
dataset_onehot2.drop(["neighbourhood"], axis=1, inplace=True)
X2= dataset_onehot2.loc[:, dataset_onehot1.columns != 'price']
Y2 = dataset_onehot2["price"]
x_train2, x_test2, y_train2, y_test2 = train_test_split(X2, Y2, test_size=0.20, random_state=42)
### Fitting Linear regression
reg2 = LinearRegression().fit(x_train2, y_train2)

# %%
### R squared value
reg2.score(x_train2, y_train2)
# Out:
# 0.5065197022244532

# %% [markdown]
# we see that the R2 is above 0.5 this is mean that the model goes well

# %%
# let's look inside the model
print("b1:",reg2.coef_)
print("b0:",reg2.intercept_)
# Out:
# b1: [-7.46582595e-01 -7.89570953e-03 -1.62398944e+00  1.44109036e-01
#   4.52313383e-02  2.14922405e-01  1.88713812e+01  4.33465572e+01
#   9.05608600e+00  5.22836756e-01 -6.58629189e+01 -8.87899100e+01]
# b0: 109.7170771190701

# %%
### Predicting 
y_pred2 = reg2.predict(x_test2)

Coeff2 = pd.DataFrame(columns=["Variable","Coefficient"])
Coeff2["Variable"]=x_train2.columns
Coeff2["Coefficient"]=reg2.coef_
Coeff2.sort_values("Coefficient")
# Out:
#                           Variable  Coefficient
# 11                  rt_Shared room   -88.789910
# 10                 rt_Private room   -65.862919
# 2                reviews_per_month    -1.623989
# 0                   minimum_nights    -0.746583
# 1                number_of_reviews    -0.007896
# 4                 availability_365     0.045231
# 3   calculated_host_listings_count     0.144109
# 5                      name_length     0.214922
# 9                 ng_Staten Island     0.522837
# 8                        ng_Queens     9.056086
# 6                      ng_Brooklyn    18.871381
# 7                     ng_Manhattan    43.346557

# %%
df_pred2 = pd.DataFrame({'Actual': y_test2, 'Predicted': y_pred2})
df_pred2
# Out:
#        Actual   Predicted
# 34997      90   92.088938
# 10452      48   46.342804
# 1303      150  132.433292
# 3160       38   76.566548
# 38227     165  155.959515
# ...       ...         ...
# 7455      110   65.697515
# 8547      199   84.610691
# 23573      52   92.480049
# 34079      72   88.754269
# 15116      98  132.347131
#
# [8532 rows x 2 columns]

# %%
plt.scatter(x=y_test2,y=y_pred2,c='g',marker='s')
plt.plot(y_pred2,y_pred2,c='b',linewidth=3)

# %% [markdown]
# # Model Interpretation
# Now that we have the results of our model, lets try to interpret it in detail.
#
# 1. We first look at the Adjusted R square value since this is a Multiple linear regression. It tell us that our independent variables can explain 50.6% of variations in our dependent variable, which is price.
#
# 2. The constant or the y intercept has a value of 109.56. This means that putting all other x variables at 0, an Entire Apt/Home in Bronx will have a predicted price of 109.56. Remember when we created dummy variables we dropped one dummy from each column which we use as reference. the dropen dummies was: Entire Apt/Home and Bronx.
#
# 3. Let's now look at the coefficients. The coefficient of ng_Manhattan is 43.34. We interpret as: Everything else being constant, an Entire Apt/ Home in Manhattan will cost 43.34 more that same in Bronx. We can similarly interpret coefficient of minimum night as: With everything else being constant, with every one unit increase in minimum number of nights, the predicted price decreases by 0.8075.

# %% [markdown]
# now lets try to use the neighbourhood variable

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
dataset_onehot2 = pd.get_dummies(df,
                                 columns=['neighbourhood_group',"neighbourhood","room_type"], 
                                 prefix = ['ng',"nh","rt"],
                                 drop_first=True)

# %%
XL1 = dataset_onehot2.loc[:, dataset_onehot2.columns != 'price']
YL1 = dataset_onehot2["price"]

# %%
x_trainL11, x_testL11, y_trainL11, y_testL11 = train_test_split(XL1, YL1, test_size=0.20, random_state=42)
regL1 = Lasso(alpha=0.01)

# %%
regL1.fit(x_trainL11, y_trainL11) 
print(regL1.score(x_trainL11, y_trainL11))
# Out:
# 0.569685959967525

# %%
dataset_onehot2.shape
# Out:
# (42658, 231)

# %%
CoeffLS1 = pd.DataFrame(columns=["Variable","Coefficients"])
CoeffLS1["Variable"]=x_trainL11.columns
CoeffLS1["Coefficients"]=regL1.coef_
CoeffLS1.sort_values("Coefficients", ascending = False)
# Out:
#                   Variable  Coefficients
# 7             ng_Manhattan     50.171404
# 62                nh_DUMBO     39.923687
# 212        nh_Vinegar Hill     37.963349
# 34     nh_Brooklyn Heights     27.832630
# 52          nh_Cobble Hill     25.493142
# ..                     ...           ...
# 102              nh_Harlem    -26.949070
# 214  nh_Washington Heights    -39.732568
# 111              nh_Inwood    -43.119278
# 228        rt_Private room    -61.951748
# 229         rt_Shared room    -84.334911
#
# [230 rows x 2 columns]

# %% [markdown]
# the neighbourhood is relative to Allerton

# %% [markdown]
# # SVM - SVC Algorithm

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(x_train1, y_train1)

#Predict the response for test dataset
y_pred = clf.predict(x_test1)

# %%
y_pred

# %%
# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test1, y_pred))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test1, y_pred))
